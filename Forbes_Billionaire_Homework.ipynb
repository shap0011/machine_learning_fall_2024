# %% [markdown]
# <a href="https://colab.research.google.com/github/shap0011/machine_learning_fall_2024/blob/main/Forbes_Billionaire_Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## In Class Practice with Pandas

# %% [markdown]
# **Data Dictionary**
#
# * Name - Name of the person
# * Net worth in billions - Net worth of the person in billions
# * Country - Country where the person is from
# * Source - Source of the income
# * Rank - Rank of the person in the Billionaires list
# * Age - Age of the person
# * Industry - Industry to which the person is related to

# %%
# mount to /content/drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Importing Pandas Library

# %%
import pandas as pd

# %% [markdown]
# ### Loading the dataset in a pandas dataframe

# %%
# df = pd.read_csv('Forbes-list-2020.csv')
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Forbes-list-2020.csv')

# %% [markdown]
# ### Print top 5 rows

# %%
df.head()
# Out:
#                        Name  NetWorth in billions        Country  \
# 0                Jeff Bezos                 177.0  United States
# 1                 Elon Musk                 151.0  United States
# 2  Bernard Arnault & family                 150.0         France
# 3                Bill Gates                 124.0  United States
# 4           Mark Zuckerberg                  97.0  United States
#
#           Source  Rank  Age          Industry
# 0         Amazon     1   57        Technology
# 1  Tesla, SpaceX     2   49        Automotive
# 2           LVMH     3   72  Fashion & Retail
# 3      Microsoft     4   65        Technology
# 4       Facebook     5   36        Technology

# %%
df.tail()
# Out:
#                    Name  NetWorth in billions Country        Source  Rank  \
# 2750  Daniel Yong Zhang                   1.0   China    e-commerce  2674
# 2751      Zhang Yuqiang                   1.0   China    Fiberglass  2674
# 2752      Zhao Meiguang                   1.0   China   gold mining  2674
# 2753     Zhong Naixiong                   1.0   China  conglomerate  2674
# 2754    Zhou Wei family                   1.0   China      Software  2674
#
#       Age         Industry
# 2750   49       Technology
# 2751   65    Manufacturing
# 2752   58  Metals & Mining
# 2753   58      Diversified
# 2754   54       Technology

# %% [markdown]
# #### <span style="color:crimson">Q1. Whose name is assigned to the 0th index in the dataframe</span>

# %%
df.loc[0:0,'Name']
# Out:
# 0    Jeff Bezos
# Name: Name, dtype: object

# %% [markdown]
# ### Print the dimensions of data

# %%
df.shape
# Out:
# (2755, 7)

# %% [markdown]
# #### <span style="color:crimson">Q2. How many records do you have in this dataset?</span>

# %%
df.tail(1)
# Out:
#                  Name  NetWorth in billions Country    Source  Rank  Age  \
# 2754  Zhou Wei family                   1.0   China  Software  2674   54
#
#         Industry
# 2754  Technology

# %%
# number of records (rows)
df.shape[0]
# Out:
# 2755

# %%
# number of attributes (columns)
df.shape[1]
# Out:
# 7

# %% [markdown]
# ### Datatypes of all the fields in the data

# %%
df.dtypes
# Out:
# Name                     object
# NetWorth in billions    float64
# Country                  object
# Source                   object
# Rank                      int64
# Age                       int64
# Industry                 object
# dtype: object

# %% [markdown]
# #### <span style="color:crimson">Q3. What is the data type of the variable Source</span>

# %%
df.dtypes['Source']
# Out:
# dtype('O')

# %% [markdown]
# ### Checking for missing values

# %% [markdown]
# ##### Using buil-in checks

# %%
df.isna().sum()
# Out:
# Name                    0
# NetWorth in billions    0
# Country                 0
# Source                  0
# Rank                    0
# Age                     0
# Industry                0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Name                    0
# NetWorth in billions    0
# Country                 0
# Source                  0
# Rank                    0
# Age                     0
# Industry                0
# dtype: int64

# %% [markdown]
# ##### Checking data values

# %%
df['Name'].value_counts()
# Out:
# Name
# Robert Miller             2
# Li Li                     2
# Wang Yanqing & family     2
# Chen Guoxiang & family    1
# Tony Chen                 1
#                          ..
# Frank VanderSloot         1
# Kelcy Warren              1
# Xu Yi                     1
# Vladimir Yevtushenkov     1
# Zhou Wei family           1
# Name: count, Length: 2752, dtype: int64

# %%
df['NetWorth in billions'].value_counts()
# Out:
# NetWorth in billions
# 1.1     150
# 1.2     146
# 1.4     122
# 1.3     115
# 1.5     106
#        ...
# 19.4      1
# 19.1      1
# 19.0      1
# 18.8      1
# 13.7      1
# Name: count, Length: 245, dtype: int64

# %%
df['Country'].value_counts()
# Out:
# Country
# United States           724
# China                   626
# India                   140
# Germany                 136
# Russia                  118
#                        ...
# Venezuela                 1
# Eswatini (Swaziland)      1
# Algeria                   1
# Liechtenstein             1
# Nepal                     1
# Name: count, Length: 70, dtype: int64

# %%
df['Source'].value_counts()
# Out:
# Source
# real estate                171
# pharmaceuticals             99
# investments                 90
# diversified                 85
# software                    62
#                           ...
# TV network, investments      1
# media, tech                  1
# aluminum, diversified        1
# measuring instruments        1
# gold mining                  1
# Name: count, Length: 924, dtype: int64

# %%
df['Rank'].value_counts()
# Out:
# Rank
# 2524    150
# 2378    146
# 2141    122
# 2263    115
# 2035    106
#        ...
# 93        1
# 94        1
# 95        1
# 98        1
# 154       1
# Name: count, Length: 245, dtype: int64

# %%
df['Age'].value_counts()
# Out:
# Age
# 58    105
# 57    103
# 55     90
# 59     85
# 67     84
#      ...
# 24      2
# 27      1
# 18      1
# 26      1
# 25      1
# Name: count, Length: 75, dtype: int64

# %%
df['Industry'].value_counts()
# Out:
# Industry
# Finance & Investments         371
# Technology                    365
# Manufacturing                 331
# Fashion & Retail              273
# Healthcare                    221
# Food & Beverage               219
# Real Estate                   215
# Diversified                   188
# Energy                        100
# Media & Entertainment          95
# Service                        75
# Metals & Mining                74
# Automotive                     68
# Construction & Engineering     44
# Logistics                      35
# Telecom                        32
# Gambling & Casinos             25
# Sports                         24
# Name: count, dtype: int64

# %% [markdown]
# ##### Checking type of column

# %%
df.dtypes
# Out:
# Name                     object
# NetWorth in billions    float64
# Country                  object
# Source                   object
# Rank                      int64
# Age                       int64
# Industry                 object
# dtype: object

# %% [markdown]
# ##### Sorting the values

# %%
df['Name'].sort_values()
# Out:
# 2673                          A. Jayson Adair
# 1444              Abdulla Al Futtaim & family
# 1111    Abdulla bin Ahmad Al Ghurair & family
# 580                          Abdulsamad Rabiu
# 1315                            Abhay Firodia
#                         ...
# 2260                                 Zhuo Jun
# 2148                               Ziv Aviram
# 272                              Zong Qinghou
# 129                                   Zuo Hui
# 978                        Zygmunt Solorz-Zak
# Name: Name, Length: 2755, dtype: object

# %%
df['NetWorth in billions'].sort_values()
# Out:
# 2754      1.0
# 2694      1.0
# 2695      1.0
# 2696      1.0
# 2697      1.0
#         ...
# 4        97.0
# 3       124.0
# 2       150.0
# 1       151.0
# 0       177.0
# Name: NetWorth in billions, Length: 2755, dtype: float64

# %%
df['Country'].sort_values()
# Out:
# 597       Algeria
# 927     Argentina
# 1336    Argentina
# 2292    Argentina
# 1494    Argentina
#           ...
# 1964      Vietnam
# 1147      Vietnam
# 1504      Vietnam
# 2457      Vietnam
# 2087     Zimbabwe
# Name: Country, Length: 2755, dtype: object

# %%
df['Source'].sort_values()
# Out:
# 1266                 3D printing
# 2044                         AOL
# 153                       Airbnb
# 178                       Airbnb
# 176                       Airbnb
#                   ...
# 886                         wine
# 2745                        wine
# 912               winter jackets
# 1912       wire & cables, paints
# 99      wireless networking gear
# Name: Source, Length: 2755, dtype: object

# %%
df['Rank'].sort_values()
# Out:
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
#         ...
# 2696    2674
# 2695    2674
# 2694    2674
# 2692    2674
# 2754    2674
# Name: Rank, Length: 2755, dtype: int64

# %%
df['Age'].sort_values()
# Out:
# 940     18
# 2143    24
# 2122    24
# 2144    25
# 1338    26
#         ..
# 729     96
# 1579    96
# 1626    97
# 1559    97
# 170     97
# Name: Age, Length: 2755, dtype: int64

# %%
df['Industry'].sort_values()
# Out:
# 1949    Automotive
# 2336    Automotive
# 2568    Automotive
# 2245    Automotive
# 482     Automotive
#            ...
# 478        Telecom
# 213        Telecom
# 351        Telecom
# 2472       Telecom
# 2668       Telecom
# Name: Industry, Length: 2755, dtype: object

# %% [markdown]
# #### <span style="color:crimson">Q4. How many missing values exists in the industry feature</span>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2755 entries, 0 to 2754
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name                  2755 non-null   object
#  1   NetWorth in billions  2755 non-null   float64
#  2   Country               2755 non-null   object
#  3   Source                2755 non-null   object
#  4   Rank                  2755 non-null   int64
#  5   Age                   2755 non-null   int64
#  6   Industry              2755 non-null   object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 150.8+ KB

# %%
df['Industry'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 2755 entries, 0 to 2754
# Series name: Industry
# Non-Null Count  Dtype
# --------------  -----
# 2755 non-null   object
# dtypes: object(1)
# memory usage: 21.6+ KB

# %%
df['Industry'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Print the basic stats for this dataset

# %%
df.mean(numeric_only = True)
# Out:
# NetWorth in billions       4.749220
# Rank                    1345.663521
# Age                       63.014519
# dtype: float64

# %%
df.describe()
# Out:
#        NetWorth in billions         Rank          Age
# count           2755.000000  2755.000000  2755.000000
# mean               4.749220  1345.663521    63.014519
# std                9.615358   772.669811    13.259017
# min                1.000000     1.000000    18.000000
# 25%                1.500000   680.000000    54.000000
# 50%                2.300000  1362.000000    62.000000
# 75%                4.200000  2035.000000    72.000000
# max              177.000000  2674.000000    97.000000

# %% [markdown]
# #### <span style="color:crimson">Q5. Who is the yongest billionare in this list?</span>

# %%
df['Name'][df['Age'] == df['Age'].min()]
# Out:
# 940    Kevin David Lehmann
# Name: Name, dtype: object

# %%
df[['Name', 'Age']].sort_values('Age', ascending = True).head(1)
# Out:
#                     Name  Age
# 940  Kevin David Lehmann   18

# %% [markdown]
# ### Sort the dataset  by Age (ascending) and reset the index

# %%
#df_sorted_by_age = df.sort_values('Age', ascending = True)
#df_sorted_by_age
df = df.sort_values('Age', ascending = True)
df
# Out:
#                      Name  NetWorth in billions        Country  \
# 940   Kevin David Lehmann                   3.3        Germany
# 2143   Alexandra Andresen                   1.4         Norway
# 2122          Wang Zelong                   1.5          China
# 2144   Katharina Andresen                   1.4         Norway
# 1338       Austin Russell                   2.4  United States
# ...                   ...                   ...            ...
# 729         Masatoshi Ito                   4.0          Japan
# 1579    S. Daniel Abraham                   2.0  United States
# 1626       Charles Munger                   2.0  United States
# 1559        David Murdock                   2.1  United States
# 170           Robert Kuok                  12.6       Malaysia
#
#                             Source  Rank  Age               Industry
# 940                     drugstores   925   18       Fashion & Retail
# 2143                   investments  2141   24            Diversified
# ...

# %%
#new_index = list(range(df.shape[0]))

# %%
#new_index[-1]

# %%
# how many records
df.shape[0]
# Out:
# 2755

# %%
#df_sorted_by_age_ri = df_sorted_by_age.reset_index()
#df_sorted_by_age_ri
df = df.reset_index()
df
# Out:
#       index                 Name  NetWorth in billions        Country  \
# 0       940  Kevin David Lehmann                   3.3        Germany
# 1      2143   Alexandra Andresen                   1.4         Norway
# 2      2122          Wang Zelong                   1.5          China
# 3      2144   Katharina Andresen                   1.4         Norway
# 4      1338       Austin Russell                   2.4  United States
# ...     ...                  ...                   ...            ...
# 2750    729        Masatoshi Ito                   4.0          Japan
# 2751   1579    S. Daniel Abraham                   2.0  United States
# 2752   1626       Charles Munger                   2.0  United States
# 2753   1559        David Murdock                   2.1  United States
# 2754    170          Robert Kuok                  12.6       Malaysia
#
#                             Source  Rank  Age               Industry
# ...

# %%
# run
# loc - selecting things by label
# df.loc[0, :]
# df.loc[[0,1,2], :] this is same as
# df.loc[0:2, :]
# df.loc[:, ['Name','Age']]
# df.loc[:, 'Name' : 'Age']
# df.loc[0:2, 'Name':'Age'] 0:2 - inclusive in both sides
# df.head(3).drop('Industry', axis=1)
# df[df.Country=='Ukraine']
# df.loc[df.Country=='Ukraine', :]
# df[df.Country=='Ukraine'].Name - bad practice
# df.loc[df.Country=='Ukraine', 'Name']

# %%
df.columns
# Out:
# Index(['index', 'Name', 'NetWorth in billions', 'Country', 'Source', 'Rank',
#        'Age', 'Industry'],
#       dtype='object')

# %%
# run
# iloc - filtering rows and selecting columns by integer position
# df.iloc[:, [0, 3]]
# df.iloc[:, 0:4] exclusive last one (4), right side
df.iloc[0:3, :]
# Out:
#    index                 Name  NetWorth in billions  Country       Source  \
# 0    940  Kevin David Lehmann                   3.3  Germany   drugstores
# 1   2143   Alexandra Andresen                   1.4   Norway  investments
# 2   2122          Wang Zelong                   1.5    China    chemicals
#
#    Rank  Age          Industry
# 0   925   18  Fashion & Retail
# 1  2141   24       Diversified
# 2  2035   24   Metals & Mining

# %%
# df[['Name', 'Country']] - bad, too much logic
# df.loc[:, ['Name', 'Country']]
# df[0:2] - bad, too much logic
df.iloc[0:2, :]
# Out:
#    index                 Name  NetWorth in billions  Country       Source  \
# 0    940  Kevin David Lehmann                   3.3  Germany   drugstores
# 1   2143   Alexandra Andresen                   1.4   Norway  investments
#
#    Rank  Age          Industry
# 0   925   18  Fashion & Retail
# 1  2141   24       Diversified

# %%
# df2 = pd.read_csv('Forbes-list-2020.csv', index_col='Name')
df2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Forbes-list-2020.csv', index_col='Name')

# %%
df2.head()
# Out:
#                           NetWorth in billions        Country         Source  \
# Name
# Jeff Bezos                               177.0  United States         Amazon
# Elon Musk                                151.0  United States  Tesla, SpaceX
# Bernard Arnault & family                 150.0         France           LVMH
# Bill Gates                               124.0  United States      Microsoft
# Mark Zuckerberg                           97.0  United States       Facebook
#
#                           Rank  Age          Industry
# Name
# Jeff Bezos                   1   57        Technology
# Elon Musk                    2   49        Automotive
# Bernard Arnault & family     3   72  Fashion & Retail
# Bill Gates                   4   65        Technology
# Mark Zuckerberg              5   36        Technology

# %% [markdown]
# #### <span style="color:crimson">Q6. What is the output of `df.iloc[1200,3]`?</span>

# %%
df.iloc[1200,3]
# Out:
# 'Germany'

# %% [markdown]
# ### Create a new column `Year_of_birth`
# Note: The dataset is from the year 2020. The age of those Billionaires is as of 2020.

# %%
# create a new column 'Year_of_birth'
df['Year_of_birth'] = 2020 - df['Age']

# %%
#view the data
df
# Out:
#       index                 Name  NetWorth in billions        Country  \
# 0       940  Kevin David Lehmann                   3.3        Germany
# 1      2143   Alexandra Andresen                   1.4         Norway
# 2      2122          Wang Zelong                   1.5          China
# 3      2144   Katharina Andresen                   1.4         Norway
# 4      1338       Austin Russell                   2.4  United States
# ...     ...                  ...                   ...            ...
# 2750    729        Masatoshi Ito                   4.0          Japan
# 2751   1579    S. Daniel Abraham                   2.0  United States
# 2752   1626       Charles Munger                   2.0  United States
# 2753   1559        David Murdock                   2.1  United States
# 2754    170          Robert Kuok                  12.6       Malaysia
#
#                             Source  Rank  Age               Industry  \
# ...

# %% [markdown]
# ### Select Billionaires born in 1996

# %%
# Using where condition
filtered_df = df.loc[:,['Name','Year_of_birth']].where(df['Year_of_birth'] == 1996)
billioners_1996 = filtered_df.dropna()
billioners_1996
# Out:
#                  Name  Year_of_birth
# 1  Alexandra Andresen         1996.0
# 2         Wang Zelong         1996.0

# %% [markdown]
# #### <span style="color:crimson">Q7. How many Billionaires were born in 1996?</span>

# %%
billioners_1996.count()
# Out:
# Name             2
# Year_of_birth    2
# dtype: int64
